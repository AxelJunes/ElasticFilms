# %%
import requests
import json
from elasticsearch import Elasticsearch

# %%
res= requests.get('http://localhost:9200')

# %%
print res.content
# Out:
# {
#   "name" : "uMRcX8c",
#   "cluster_name" : "elasticsearch",
#   "cluster_uuid" : "u5F0UAhyQp2aBwUZVYvFOA",
#   "version" : {
#     "number" : "5.4.1",
#     "build_hash" : "2cfe0df",
#     "build_date" : "2017-05-29T16:05:51.443Z",
#     "build_snapshot" : false,
#     "lucene_version" : "6.5.1"
#   },
#   "tagline" : "You Know, for Search"
# }

# %%
es = Elasticsearch([{'host': 'localhost', 'port': 9200}])

# %%
r = requests.get('http://localhost:9200')
i = 1
while r.status_code == 200:
    # Load data from The Movie Database API
    r = requests.get('https://api.themoviedb.org/3/movie/' + str(i) + '?api_key=f93291a0157ffd416fde2b0ba87d6a4c&query="hardware"')
    es.index(index='movies',doc_type='movie_id', id=i, body=json.loads(r.content))
    i = i+1
print(i)
# Out:
# 2

# %%
import tmdbsimple as tmdb

# %%
tmdb.API_KEY = 'f93291a0157ffd416fde2b0ba87d6a4c'

# %%
movie = tmdb.Movies(603)

# %%
response = movie.info()

# %%
movie.title
# Out:
# u'The Matrix'
